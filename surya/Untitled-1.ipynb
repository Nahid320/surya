# %%
import json
# Load data from JSON file
with open('./results.json', 'r') as f:
    data = json.load(f)
# Accessing data

# %%
data
# Out:
# {'page1': [{'bboxes': [{'polygon': [[1367, 2032],
#       [1593, 2032],
#       [1593, 2060],
#       [1367, 2060]],
#      'confidence': 1.0,
#      'label': 'Page-footer',
#      'bbox': [1367, 2032, 1593, 2060]},
#     {'polygon': [[1451, 85], [1604, 100], [1591, 148], [1438, 133]],
#      'confidence': 1.0,
#      'label': 'Figure',
#      'bbox': [1451, 85, 1604, 148]},
#     {'polygon': [[1419, 96], [1450, 96], [1450, 123], [1419, 123]],
#      'confidence': 1.0,
#      'label': 'Figure',
#      'bbox': [1419, 96, 1450, 123]},
#     {'polygon': [[1348, 919], [1397, 890], [1415, 901], [1367, 930]],
#      'confidence': 1.0,
#      'label': 'Figure',
#      'bbox': [1348, 901, 1397, 919]},
#     {'polygon': [[1213, 945], [1286, 945], [1286, 987], [1213, 987]],
#      'confidence': 1.0,
#      'label': 'Figure',
#      'bbox': [1213, 945, 1286, 987]},
#     {'polygon': [[991, 1017], [1396, 1017], [1396, 1129], [991, 1129]],
#      'confidence': 1.0,
#      'label': 'Figure',
# ...
